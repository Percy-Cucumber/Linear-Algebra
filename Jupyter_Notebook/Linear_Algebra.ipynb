# %% [markdown]
# # Adam's Test Code
#
# ### Quest University Canada, Linearl Algebra, Richard Hoshino

# %%
# Defining the starting veriables
x=0.2
y=0.5
z=0.3
t=0

# Writing the equations
while t<100:
    x=0.8*x+0.1*y+0*z
    y=0.2*x+0.8*y+0.1*z
    z=0*x+0.1*y+0.9*z
    
# Print results and increase "t"
    print("NDP =",x*100,"    Liberal =",y*100,"    Conservative =",z*100)
    t=t+1
# Out:
# NDP = 21.000000000000004     Liberal = 47.20000000000001     Conservative = 31.720000000000002
# NDP = 21.520000000000007     Liberal = 45.23600000000002     Conservative = 33.071600000000004
# NDP = 21.73960000000001     Liberal = 43.84388000000001     Conservative = 34.14882800000001
# NDP = 21.77606800000001     Liberal = 42.84520040000002     Conservative = 35.018465240000005
# NDP = 21.705374440000007     Liberal = 42.11908173200002     Conservative = 35.728526889200005
# NDP = 21.576207725200007     Liberal = 41.58335961956002     Conservative = 36.31401016223601
# NDP = 21.419302142116013     Liberal = 41.181949140294826     Conservative = 36.80080406004189
# NDP = 21.253636627722294     Liberal = 40.876367043784505     Conservative = 37.20836035841615
# NDP = 21.090546006556288     Liberal = 40.64003887218048     Conservative = 37.551528209792586
# NDP = 20.93644069246308     Liberal = 40.454472057216265     Conservative = 37.84182259453496
# ...

# %%
x3=50
while x3<76:
    x1=(13/18)*x3
    x2=(7/9)*x3
    print("x1 =",x1,"     //     x2 =",x2,"     //     x3 =",x3)
    x3=x3+1
# Out:
# x1 = 36.11111111111111      //     x2 = 38.88888888888889      //     x3 = 50
# x1 = 36.833333333333336      //     x2 = 39.666666666666664      //     x3 = 51
# x1 = 37.55555555555556      //     x2 = 40.44444444444444      //     x3 = 52
# x1 = 38.27777777777778      //     x2 = 41.22222222222222      //     x3 = 53
# x1 = 39.0      //     x2 = 42.0      //     x3 = 54
# x1 = 39.72222222222222      //     x2 = 42.77777777777778      //     x3 = 55
# x1 = 40.44444444444444      //     x2 = 43.55555555555556      //     x3 = 56
# x1 = 41.166666666666664      //     x2 = 44.333333333333336      //     x3 = 57
# x1 = 41.888888888888886      //     x2 = 45.111111111111114      //     x3 = 58
# x1 = 42.61111111111111      //     x2 = 45.88888888888889      //     x3 = 59
# x1 = 43.333333333333336      //     x2 = 46.666666666666664      //     x3 = 60
# x1 = 44.05555555555556      //     x2 = 47.44444444444444      //     x3 = 61
# ...
